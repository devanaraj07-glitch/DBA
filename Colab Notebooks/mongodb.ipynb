# %% [markdown]
# <a href="https://colab.research.google.com/github/devanaraj07-glitch/DBA/blob/main/mongodb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MongoDB
#
# Devana Raj, 32146986

# %% [markdown]
# Installing python driver for MongoDB

# %%
# !pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 18.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 9.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# Connecting to MongoDB Atlas

# %%
from pymongo import MongoClient
client = MongoClient("mongodb+srv://devanaraj07_db_user:devanaraj@northstarcluster.n5fixh4.mongodb.net/?appName=NorthStarCluster")
db = client["northstar_db"]

# %% [markdown]
# Loading the datasets

# %%
from google.colab import drive
drive.mount('/content/drive')
base_path = "/content/drive/My Drive/northstar_dataset/northstar_dataset/"
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
base_path = "/content/drive/My Drive/northstar_dataset/northstar_dataset/"

# %%
orders = pd.read_csv(base_path + "orders.csv")
deliveries = pd.read_csv(base_path + "deliveries.csv")
customers = pd.read_csv(base_path + "customers.csv")
complaints = pd.read_csv(base_path + "complaints.csv")
incidents = pd.read_csv(base_path + "incidents.csv")
app_events = pd.read_csv(base_path + "app_events.csv")

# %% [markdown]
# Inserting Customers (with embedded complaints)

# %%
customer_docs = []

for _, c in customers.iterrows():
    cust_complaints = complaints[complaints["customer_id"] == c["customer_id"]]

    complaint_list = []
    for _, comp in cust_complaints.iterrows():
        complaint_list.append({
            "complaint_id": comp["complaint_id"],
            "complaint_type": comp["complaint_type"],
            "severity": comp["severity"],
            "status": comp["status"],
            "resolution_days": comp["resolution_days"]
        })

    customer_docs.append({
        "customer_id": c["customer_id"],
        "age": c["age"],
        "home_zone": c["home_zone"],
        "customer_type": c["customer_type"],
        "signup_date": c["signup_date"],
        "loyalty_score": c["loyalty_score"],
        "app_engagement_score": c["app_engagement_score"],
        "preferred_channel": c["preferred_channel"],
        "account_status": c["account_status"],
        "complaints": complaint_list
    })

db.customers.insert_many(customer_docs)
# Out:
# InsertManyResult([ObjectId('6a074bf2ea6f2355ae475357'), ObjectId('6a074bf2ea6f2355ae475358'), ObjectId('6a074bf2ea6f2355ae475359'), ObjectId('6a074bf2ea6f2355ae47535a'), ObjectId('6a074bf2ea6f2355ae47535b'), ObjectId('6a074bf2ea6f2355ae47535c'), ObjectId('6a074bf2ea6f2355ae47535d'), ObjectId('6a074bf2ea6f2355ae47535e'), ObjectId('6a074bf2ea6f2355ae47535f'), ObjectId('6a074bf2ea6f2355ae475360'), ObjectId('6a074bf2ea6f2355ae475361'), ObjectId('6a074bf2ea6f2355ae475362'), ObjectId('6a074bf2ea6f2355ae475363'), ObjectId('6a074bf2ea6f2355ae475364'), ObjectId('6a074bf2ea6f2355ae475365'), ObjectId('6a074bf2ea6f2355ae475366'), ObjectId('6a074bf2ea6f2355ae475367'), ObjectId('6a074bf2ea6f2355ae475368'), ObjectId('6a074bf2ea6f2355ae475369'), ObjectId('6a074bf2ea6f2355ae47536a'), ObjectId('6a074bf2ea6f2355ae47536b'), ObjectId('6a074bf2ea6f2355ae47536c'), ObjectId('6a074bf2ea6f2355ae47536d'), ObjectId('6a074bf2ea6f2355ae47536e'), ObjectId('6a074bf2ea6f2355ae47536f'), ObjectId('6a074bf2ea6f2355ae47
# ...

# %% [markdown]
# Inserting Deliveries (with embedded incidents)

# %%
delivery_docs = []

for _, d in deliveries.iterrows():
    related_incidents = incidents[incidents["delivery_id"] == d["delivery_id"]]

    incident_list = []
    for _, i in related_incidents.iterrows():
        incident_list.append({
            "incident_type": i["incident_type"],
            "severity": i["severity"],
            "reported_at": i["reported_at"],
            "resolution_status": i["resolution_status"],
            "resolved_hours": i["resolved_hours"]
        })

    delivery_docs.append({
        "delivery_id": d["delivery_id"],
        "order_id": d["order_id"],
        "driver_id": d["driver_id"],
        "vehicle_id": d["vehicle_id"],
        "hub_id": d["hub_id"],
        "dispatch_time": d["dispatch_time"],
        "delivery_completed_at": d["delivery_completed_at"],
        "delivery_status": d["delivery_status"],
        "route_distance_km": d["route_distance_km"],
        "manual_route_override_count": d["manual_route_override_count"],
        "proof_of_completion_missing": d["proof_of_completion_missing"],
        "customer_rating_post_delivery": d["customer_rating_post_delivery"],
        "fuel_or_charge_cost": d["fuel_or_charge_cost"],
        "incidents": incident_list
    })

db.deliveries.insert_many(delivery_docs)
# Out:
# InsertManyResult([ObjectId('6a074bf7ea6f2355ae4755e1'), ObjectId('6a074bf7ea6f2355ae4755e2'), ObjectId('6a074bf7ea6f2355ae4755e3'), ObjectId('6a074bf7ea6f2355ae4755e4'), ObjectId('6a074bf7ea6f2355ae4755e5'), ObjectId('6a074bf7ea6f2355ae4755e6'), ObjectId('6a074bf7ea6f2355ae4755e7'), ObjectId('6a074bf7ea6f2355ae4755e8'), ObjectId('6a074bf7ea6f2355ae4755e9'), ObjectId('6a074bf7ea6f2355ae4755ea'), ObjectId('6a074bf7ea6f2355ae4755eb'), ObjectId('6a074bf7ea6f2355ae4755ec'), ObjectId('6a074bf7ea6f2355ae4755ed'), ObjectId('6a074bf7ea6f2355ae4755ee'), ObjectId('6a074bf7ea6f2355ae4755ef'), ObjectId('6a074bf7ea6f2355ae4755f0'), ObjectId('6a074bf7ea6f2355ae4755f1'), ObjectId('6a074bf7ea6f2355ae4755f2'), ObjectId('6a074bf7ea6f2355ae4755f3'), ObjectId('6a074bf7ea6f2355ae4755f4'), ObjectId('6a074bf7ea6f2355ae4755f5'), ObjectId('6a074bf7ea6f2355ae4755f6'), ObjectId('6a074bf7ea6f2355ae4755f7'), ObjectId('6a074bf7ea6f2355ae4755f8'), ObjectId('6a074bf7ea6f2355ae4755f9'), ObjectId('6a074bf7ea6f2355ae47
# ...

# %% [markdown]
# Inserting orders

# %%
db.orders.insert_many(orders.to_dict("records"))
# Out:
# InsertManyResult([ObjectId('6a074bfcea6f2355ae475997'), ObjectId('6a074bfcea6f2355ae475998'), ObjectId('6a074bfcea6f2355ae475999'), ObjectId('6a074bfcea6f2355ae47599a'), ObjectId('6a074bfcea6f2355ae47599b'), ObjectId('6a074bfcea6f2355ae47599c'), ObjectId('6a074bfcea6f2355ae47599d'), ObjectId('6a074bfcea6f2355ae47599e'), ObjectId('6a074bfcea6f2355ae47599f'), ObjectId('6a074bfcea6f2355ae4759a0'), ObjectId('6a074bfcea6f2355ae4759a1'), ObjectId('6a074bfcea6f2355ae4759a2'), ObjectId('6a074bfcea6f2355ae4759a3'), ObjectId('6a074bfcea6f2355ae4759a4'), ObjectId('6a074bfcea6f2355ae4759a5'), ObjectId('6a074bfcea6f2355ae4759a6'), ObjectId('6a074bfcea6f2355ae4759a7'), ObjectId('6a074bfcea6f2355ae4759a8'), ObjectId('6a074bfcea6f2355ae4759a9'), ObjectId('6a074bfcea6f2355ae4759aa'), ObjectId('6a074bfcea6f2355ae4759ab'), ObjectId('6a074bfcea6f2355ae4759ac'), ObjectId('6a074bfcea6f2355ae4759ad'), ObjectId('6a074bfcea6f2355ae4759ae'), ObjectId('6a074bfcea6f2355ae4759af'), ObjectId('6a074bfcea6f2355ae47
# ...

# %% [markdown]
# Inserting app events

# %%
db.app_events.insert_many(app_events.to_dict("records"))
# Out:
# InsertManyResult([ObjectId('6a074c00ea6f2355ae475e79'), ObjectId('6a074c00ea6f2355ae475e7a'), ObjectId('6a074c00ea6f2355ae475e7b'), ObjectId('6a074c00ea6f2355ae475e7c'), ObjectId('6a074c00ea6f2355ae475e7d'), ObjectId('6a074c00ea6f2355ae475e7e'), ObjectId('6a074c00ea6f2355ae475e7f'), ObjectId('6a074c00ea6f2355ae475e80'), ObjectId('6a074c00ea6f2355ae475e81'), ObjectId('6a074c00ea6f2355ae475e82'), ObjectId('6a074c00ea6f2355ae475e83'), ObjectId('6a074c00ea6f2355ae475e84'), ObjectId('6a074c00ea6f2355ae475e85'), ObjectId('6a074c00ea6f2355ae475e86'), ObjectId('6a074c00ea6f2355ae475e87'), ObjectId('6a074c00ea6f2355ae475e88'), ObjectId('6a074c00ea6f2355ae475e89'), ObjectId('6a074c00ea6f2355ae475e8a'), ObjectId('6a074c00ea6f2355ae475e8b'), ObjectId('6a074c00ea6f2355ae475e8c'), ObjectId('6a074c00ea6f2355ae475e8d'), ObjectId('6a074c00ea6f2355ae475e8e'), ObjectId('6a074c00ea6f2355ae475e8f'), ObjectId('6a074c00ea6f2355ae475e90'), ObjectId('6a074c00ea6f2355ae475e91'), ObjectId('6a074c00ea6f2355ae47
# ...

# %% [markdown]
# Testing the queries

# %%
db.customers.find_one()
# Out:
# {'_id': ObjectId('6a06dbde688e453ba9201d53'),
#  'customer_id': 'C0001',
#  'age': 26,
#  'home_zone': 'North',
#  'customer_type': 'SME',
#  'signup_date': '2024-11-27 04:25:00',
#  'loyalty_score': 44.9,
#  'app_engagement_score': 69.2,
#  'preferred_channel': 'App',
#  'account_status': 'Active',
#  'complaints': [{'complaint_id': 'CP0096',
#    'complaint_type': 'AppIssue',
#    'severity': 'High',
#    'status': 'Resolved',
#    'resolution_days': 22},
#   {'complaint_id': 'CP0146',
#    'complaint_type': 'Delay',
#    'severity': 'Medium',
#    'status': 'Resolved',
#    'resolution_days': 4}]}

# %%
db.deliveries.find_one()
# Out:
# {'_id': ObjectId('6a06df8e688e453ba920273f'),
#  'delivery_id': 'DL00001',
#  'order_id': 'O00938',
#  'driver_id': 'D004',
#  'vehicle_id': 'V056',
#  'hub_id': 'H05',
#  'dispatch_time': '2024-06-18 10:57:00',
#  'delivery_completed_at': '2024-06-19 09:05:59.904311',
#  'delivery_status': 'Failed',
#  'route_distance_km': 17.26,
#  'manual_route_override_count': 1,
#  'proof_of_completion_missing': 0,
#  'customer_rating_post_delivery': 3.07,
#  'fuel_or_charge_cost': 12.05,
#  'incidents': [{'incident_type': 'ProofMissing',
#    'severity': 'High',
#    'reported_at': '2024-06-18 11:38:00',
#    'resolution_status': 'Open',
#    'resolved_hours': 5.6}]}

# %% [markdown]
# High override deliveries

# %%
list(db.deliveries.find(
    {"manual_route_override_count": {"$gte": 2}}
))
# Out:
# [{'_id': ObjectId('6a06df94688e453ba920274d'),
#   'delivery_id': 'DL00013',
#   'order_id': 'O01031',
#   'driver_id': 'D105',
#   'vehicle_id': 'V085',
#   'hub_id': 'H04',
#   'dispatch_time': '2025-01-26 08:29:00',
#   'delivery_completed_at': '2025-01-26 10:33:30.834127',
#   'delivery_status': 'OnTime',
#   'route_distance_km': 6.01,
#   'manual_route_override_count': 2,
#   'proof_of_completion_missing': 0,
#   'customer_rating_post_delivery': 3.96,
#   'fuel_or_charge_cost': 11.52,
#   'incidents': [{'incident_type': 'VehicleFault',
#     'severity': 'Medium',
#     'reported_at': '2025-01-26 10:52:00',
#     'resolution_status': 'Closed',
#     'resolved_hours': 0.2}]},
#  {'_id': ObjectId('6a06df94688e453ba920275a'),
#   'delivery_id': 'DL00026',
#   'order_id': 'O00906',
#   'driver_id': 'D092',
#   'vehicle_id': 'V055',
#   'hub_id': 'H04',
#   'dispatch_time': '2025-02-04 11:16:00',
#   'delivery_completed_at': '2025-02-06 01:48:45.831712',
# ...

# %% [markdown]
# High severity incidents

# %%
list(db.deliveries.find(
    {"incidents.severity": "High"}
))
# Out:
# [{'_id': ObjectId('6a06df8e688e453ba920273f'),
#   'delivery_id': 'DL00001',
#   'order_id': 'O00938',
#   'driver_id': 'D004',
#   'vehicle_id': 'V056',
#   'hub_id': 'H05',
#   'dispatch_time': '2024-06-18 10:57:00',
#   'delivery_completed_at': '2024-06-19 09:05:59.904311',
#   'delivery_status': 'Failed',
#   'route_distance_km': 17.26,
#   'manual_route_override_count': 1,
#   'proof_of_completion_missing': 0,
#   'customer_rating_post_delivery': 3.07,
#   'fuel_or_charge_cost': 12.05,
#   'incidents': [{'incident_type': 'ProofMissing',
#     'severity': 'High',
#     'reported_at': '2024-06-18 11:38:00',
#     'resolution_status': 'Open',
#     'resolved_hours': 5.6}]},
#  {'_id': ObjectId('6a06df94688e453ba9202741'),
#   'delivery_id': 'DL00001',
#   'order_id': 'O00938',
#   'driver_id': 'D004',
#   'vehicle_id': 'V056',
#   'hub_id': 'H05',
#   'dispatch_time': '2024-06-18 10:57:00',
#   'delivery_completed_at': '2024-06-19 09:05:59.904311',
#   'delivery_status': 'Failed',
# ...

# %% [markdown]
# Premium customers complaints

# %%
db.customers.find(
    {"customer_type": "Premium"},
    {"complaints": 1, "_id": 0}
)

# %% [markdown]
# # Query Optimisation

# %% [markdown]
# Reset Index (Baseline Setup)

# %%
db.deliveries.drop_index("hub_id_1")

# %% [markdown]
# Baseline Query Performance (Before Optimisation)

# %%
db.command({
    "explain": {
        "find": "deliveries",
        "filter": {"hub_id": "H01"}
    },
    "verbosity": "executionStats"
})
# Out:
# {'explainVersion': '1',
#  'queryPlanner': {'namespace': 'northstar_db.deliveries',
#   'parsedQuery': {'hub_id': {'$eq': 'H01'}},
#   'indexFilterSet': False,
#   'queryHash': '1EFC9250',
#   'planCacheShapeHash': '1EFC9250',
#   'planCacheKey': '448851F0',
#   'optimizationTimeMillis': 0,
#   'maxIndexedOrSolutionsReached': False,
#   'maxIndexedAndSolutionsReached': False,
#   'maxScansToExplodeReached': False,
#   'prunedSimilarIndexes': False,
#   'winningPlan': {'isCached': False,
#    'stage': 'COLLSCAN',
#    'filter': {'hub_id': {'$eq': 'H01'}},
#    'direction': 'forward'},
#   'rejectedPlans': []},
#  'executionStats': {'executionSuccess': True,
#   'nReturned': 272,
#   'executionTimeMillis': 1,
#   'totalKeysExamined': 0,
#   'totalDocsExamined': 1901,
#   'executionStages': {'isCached': False,
#    'stage': 'COLLSCAN',
#    'filter': {'hub_id': {'$eq': 'H01'}},
#    'nReturned': 272,
#    'executionTimeMillisEstimate': 0,
#    'works': 1902,
#    'advanced': 272,
# ...

# %% [markdown]
# Create Index on hub_id (Optimisation Step)

# %%
db.deliveries.create_index("hub_id")
# Out:
# 'hub_id_1'

# %% [markdown]
# Post-Index Query Verification

# %%
db.deliveries.distinct("hub_id")
# Out:
# ['H01', 'H02', 'H03', 'H04', 'H05', 'H06', 'H07', 'H08']

# %%
list(db.deliveries.find({"hub_id": "H01"}))
# Out:
# [{'_id': ObjectId('6a06df94688e453ba9202745'),
#   'delivery_id': 'DL00005',
#   'order_id': 'O00844',
#   'driver_id': 'D108',
#   'vehicle_id': 'V034',
#   'hub_id': 'H01',
#   'dispatch_time': '2025-09-21 11:43:00',
#   'delivery_completed_at': '2025-09-21 15:45:34.131056',
#   'delivery_status': 'OnTime',
#   'route_distance_km': 14.52,
#   'manual_route_override_count': 1,
#   'proof_of_completion_missing': 0,
#   'customer_rating_post_delivery': 4.18,
#   'fuel_or_charge_cost': 9.22,
#   'incidents': []},
#  {'_id': ObjectId('6a06df94688e453ba9202752'),
#   'delivery_id': 'DL00018',
#   'order_id': 'O00611',
#   'driver_id': 'D011',
#   'vehicle_id': 'V001',
#   'hub_id': 'H01',
#   'dispatch_time': '2025-07-29 10:52:00',
#   'delivery_completed_at': '2025-07-29 09:54:19.874248',
#   'delivery_status': 'OnTime',
#   'route_distance_km': 13.67,
#   'manual_route_override_count': 0,
#   'proof_of_completion_missing': 0,
#   'customer_rating_post_delivery': 4.46,
# ...

# %%
for doc in db.deliveries.find({"hub_id": "H01"}).limit(5):
    print(doc)
# Out:
# {'_id': ObjectId('6a06df94688e453ba9202745'), 'delivery_id': 'DL00005', 'order_id': 'O00844', 'driver_id': 'D108', 'vehicle_id': 'V034', 'hub_id': 'H01', 'dispatch_time': '2025-09-21 11:43:00', 'delivery_completed_at': '2025-09-21 15:45:34.131056', 'delivery_status': 'OnTime', 'route_distance_km': 14.52, 'manual_route_override_count': 1, 'proof_of_completion_missing': 0, 'customer_rating_post_delivery': 4.18, 'fuel_or_charge_cost': 9.22, 'incidents': []}
# {'_id': ObjectId('6a06df94688e453ba9202752'), 'delivery_id': 'DL00018', 'order_id': 'O00611', 'driver_id': 'D011', 'vehicle_id': 'V001', 'hub_id': 'H01', 'dispatch_time': '2025-07-29 10:52:00', 'delivery_completed_at': '2025-07-29 09:54:19.874248', 'delivery_status': 'OnTime', 'route_distance_km': 13.67, 'manual_route_override_count': 0, 'proof_of_completion_missing': 0, 'customer_rating_post_delivery': 4.46, 'fuel_or_charge_cost': 16.18, 'incidents': []}
# ...

# %%
db.deliveries.count_documents({"hub_id": "H01"})
# Out:
# 272

# %% [markdown]
#  Index Optimisation (Schema Tuning)

# %%
db.deliveries.create_index("customer_id")
db.deliveries.create_index("manual_route_override_count")
db.deliveries.create_index("delivery_id")
db.customers.create_index("customer_id")
# Out:
# 'customer_id_1'

# %% [markdown]
# Optimised Query Performance (After Indexing)

# %%
db.command({
    "explain": {
        "find": "deliveries",
        "filter": {"hub_id": "H01"}
    },
    "verbosity": "executionStats"
})
# Out:
# {'explainVersion': '1',
#  'queryPlanner': {'namespace': 'northstar_db.deliveries',
#   'parsedQuery': {'hub_id': {'$eq': 'H01'}},
#   'indexFilterSet': False,
#   'queryHash': '1EFC9250',
#   'planCacheShapeHash': '1EFC9250',
#   'planCacheKey': '97CDBB32',
#   'optimizationTimeMillis': 0,
#   'maxIndexedOrSolutionsReached': False,
#   'maxIndexedAndSolutionsReached': False,
#   'maxScansToExplodeReached': False,
#   'prunedSimilarIndexes': False,
#   'winningPlan': {'isCached': False,
#    'stage': 'FETCH',
#    'inputStage': {'stage': 'IXSCAN',
#     'keyPattern': {'hub_id': 1},
#     'indexName': 'hub_id_1',
#     'isMultiKey': False,
#     'multiKeyPaths': {'hub_id': []},
#     'isUnique': False,
#     'isSparse': False,
#     'isPartial': False,
#     'indexVersion': 2,
#     'direction': 'forward',
#     'indexBounds': {'hub_id': ['["H01", "H01"]']}}},
#   'rejectedPlans': []},
#  'executionStats': {'executionSuccess': True,
#   'nReturned': 272,
#   'executionTimeMillis': 0,
# ...
